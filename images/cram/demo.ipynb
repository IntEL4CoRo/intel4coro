# %% [markdown]
# # CRAM Tutorials with Rvizweb
#
# Introduction text, overview of this lecture.
#
# ## How to use Jupyter and execute code
#
# Click into the code block and press CTRL-ENTER to execute the code.

# %% [markdown]
# ### 1. Loading the CRAM package *cram-projection-demos*
#
# Load the demo package and wait for the start to turn into a number. It will say something about `BAD-SYSTEM-NAME` but that's from 3rd-party software and just a style-warning. You can condense the huge outprint by clicking on the blue vertical bar left to the outprint or right click the output and Enable Scrolling for Outputs

# %%
(asdf:load-system :cram-projection-demos)
# Out:
# T
# BAD-SYSTEM-NAME: System definition file #P"/home/jovyan/workspace/ros/src/cram/cram_3rdparty/cl_store/src/cl-store.asd" contains definition for system "cl-store-tests". Please only define "cl-store" and secondary systems with a name starting with "cl-store/" (e.g. "cl-store/test") in that file.
# BAD-SYSTEM-NAME: System definition file #P"/home/jovyan/workspace/ros/src/cram/cram_3rdparty/cl_ppcre/src/cl-ppcre.asd" contains definition for system "cl-ppcre-test". Please only define "cl-ppcre" and secondary systems with a name starting with "cl-ppcre/" (e.g. "cl-ppcre/test") in that file.
# BAD-SYSTEM-NAME: System definition file #P"/home/jovyan/workspace/ros/src/cram/cram_3rdparty/split_sequence/src/split-sequence.asd" contains definition for system "split-sequence-tests". Please only define "split-sequence" and secondary systems with a name starting with "split-sequence/" (e.g. "split-sequence/test") in that file.
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining LISP-UNIT:NUMERICAL-EQUAL (#<STANDARD-CLASS GRID:FOREIGN-ARRAY>
#                                                                              #<STANDARD-CLASS GRID:FOREIGN-ARRAY>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining CRAM-MANIPULATION-INTERFACES::SYMBOL-TO-PROLOG-RULE in DEFUN
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :CUTLERY>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :CUTLERY>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :FORK>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :FORK>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :KNIFE>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :KNIFE>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :SPOON>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :SPOON>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :SPATULA>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :SPATULA>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAKFAST-CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAKFAST-CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAKFAST-CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BREAKFAST-CEREAL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP-FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP-FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP-LEFT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP-LEFT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP-RIGHT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOWL>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP-RIGHT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOLT>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :BOLT>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :TOP>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DISH-WASHER-TABS>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DISH-WASHER-TABS>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DISH-WASHER-TABS>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :BACK>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :BACK>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :BACK>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :BACK>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :BACK>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :FRONT>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :FRONT>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :HEITMANN-CITRONENSAEURE>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :LEFT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-TRANSFORM (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                      #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                      #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-TO-GRIPPER-PREGRASP-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SB-KERNEL:REDEFINITION-WITH-DEFMETHOD: redefining CRAM-MANIPULATION-INTERFACES:GET-OBJECT-TYPE-WRT-BASE-FRAME-LIFT-TRANSFORMS (#<SB-MOP:EQL-SPECIALIZER :DOMESTOS-ALLZWECKREINIGER>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT>
#                                                                                                                                #<SB-MOP:EQL-SPECIALIZER :RIGHT-SIDE>
#                                                                                                                                #<SB-PCL:SYSTEM-CLASS COMMON-LISP:T>) in DEFMETHOD
# SIMPLE-WARNING: Normalized rotation component to #<QUATERNION (0.7071067811865475d0 0.7071067811865475d0 0.0d0 0.0d0)>
# SB-KERNEL:REDEFINITION-WITH-DEFUN: redefining CRAM-PROJECTION-DEMOS::FINALIZE in DEFUN

# %% [markdown]
# The following macro boots necessary settings for the `cram-projection-demos` package and it's dependencies, and establishes the ROS connection to the roscore, running in the background, the docker container. This will open up the Bulled Physics simulator, including the environment and the robot.

# %%
(roslisp-utilities:startup-ros)
# Out:
# NIL
# [(ROSLISP TOP) INFO] 1683912354.565: Node name is /cram_hl_545859_1683912354
# [(ROSLISP TOP) INFO] 1683912354.565: Namespace is /
# [(ROSLISP TOP) INFO] 1683912354.565: Params are NIL
# [(ROSLISP TOP) INFO] 1683912354.565: Remappings are:
# [(ROSLISP TOP) INFO] 1683912354.565: master URI is 127.0.0.1:11311
# [(ROSLISP TOP) INFO] 1683912358.665: Node startup complete
# [(ROSNODE) INFO] 1683912358.670: ROS init #<FUNCTION CRAM-TF::INIT-TF>.
# [(CRAM-TF INIT-TF) INFO] 1683912358.671: Set *fixed-frame* to "map".
# [(CRAM-TF INIT-TF) INFO] 1683912358.700: Environment name is IAI-KITCHEN.
# [(CRAM-TF INIT-TF) INFO] 1683912358.728: Initialized *transformer* to a TRANSFORM-LISTENER.
# [(CRAM-TF INIT-TF) INFO] 1683912358.728: *tf-default-timeout* is 4.0.
# [(CRAM-TF INIT-TF) INFO] 1683912358.747: Robot name is PR2.
# [(CRAM-TF INIT-TF) INFO] 1683912358.753: Set *ODOM-FRAME* to "odom_combined".
# [(CRAM-TF INIT-TF) INFO] 1683912358.753: Set *ROBOT-BASE-FRAME* to "base_footprint".
# [(CRAM-TF INIT-TF) INFO] 1683912358.753: Set *ROBOT-TORSO-FRAME* to "torso_lift_link".
# [(CRAM-TF INIT-TF) INFO] 1683912358.753: Set *ROBOT-TORSO-JOINT* to "torso_lift_joint".
# [(CRAM-TF INIT-TF) INFO] 1683912358.753: Set *ROBOT-LEFT-TOOL-FRAME* to "l_gripper_tool_frame".
# [(CRAM-TF INIT-TF) INFO] 1683912358.753: Set *ROBOT-RIGHT-TOOL-FRAME* to "r_gripper_tool_frame".
# [(ROSNODE) INFO] 1683912358.753: ROS init #<FUNCTION CRAM-TF::INIT-TF-BROADCASTER>.
# [(ROSNODE) INFO] 1683912358.755: ROS init #<FUNCTION CRAM-TF::INIT-MARKER-PUBLISHER>.
# [(ROSNODE) INFO] 1683912358.756: ROS init #<FUNCTION CRAM-LOCATION-COSTMAP::LOCATION-COSTMAP-VIS-INIT>.
# [(ROSNODE) INFO] 1683912358.757: ROS init #<FUNCTION CRAM-BULLET-REASONING-BELIEF-STATE::ROS-TIME-INIT>.
# [(ROSNODE) INFO] 1683912358.757: ROS init #<FUNCTION CRAM-PROJECTION-DEMOS::INIT-PROJECTION>.
# [(SET-ROBOT-STATE-FROM-TF) WARN] 1683912368.374: Failed with transform-stamped-error:
#     No transform was published between frames base_footprint and map
#     Ignore this warning if no real robot is running.

# %% [markdown]
# Now open a new tab and launch the `Rvizweb`. You should see the kitchen scene with a PR2 robot.

# %% [markdown]
# Now, execute the demo.

# %%
(demos:household-demo)

# %%
(demos:assembly-demo)

# %%
(urdf-proj:with-simulated-robot
 (perform (a motion
             (type moving-torso)
             (joint-angle 0.3))))
# Out:
# SIMPLE-ERROR: Asserted
#   ((SIGNAL (RESULT TASK)))
# not to return. But we did return.
# 0: ((FLET "ERROR65" :IN CRAM-PROJECTION::BODY-FUNCTION) Asserted
#   ((SIGNAL (RESULT TASK)))
# not to return. But we did return.)
# 1: ((FLET "H2" :IN CRAM-PROJECTION::BODY-FUNCTION) Asserted
#   ((SIGNAL (RESULT TASK)))
# not to return. But we did return.)
# 2: (SB-KERNEL::%SIGNAL Asserted
#   ((SIGNAL (RESULT TASK)))
# not to return. But we did return.)
# 3: (ERROR Asserted~%  ~@<~A~:>~%not to return. But we did return. ((SIGNAL (RESULT TASK))))
# 4: (CRAM-UTILITIES::%ASSERT-NO-RETURNING ((SIGNAL (RESULT TASK))) #<CLOSURE (LAMBDA NIL :IN CRAM-LANGUAGE-IMPLEMENTATION:JOIN-TASK) {1005DCEB0B}>)
# 5: ((:METHOD CRAM-LANGUAGE-IMPLEMENTATION:JOIN-TASK (CRAM-LANGUAGE-IMPLEMENTATION::ABSTRACT-TASK)) #<TOPLEVEL-TASK "[TOP-LEVEL-TOP-LEVEL]-37" {1005DCB263}>)
# 6: ((FLET CRAM-PROJECTION::BODY-FUNCTION :IN "/tmp/53933552D1DA4A480FEE593437772C7C-4114736410.lisp"))
# 7: ((LAMBDA (FUNCTION) :IN "/home/jovyan/workspace/ros/src/cram/cram_3d_world/cram_urdf_projection/src/projection-environment.lisp") #<FUNCTION (FLET CRAM-PROJECTION::BODY-FUNCTION :IN "/tmp/53933552D1DA4A480FEE593437772C7C-4114736410.lisp") {53C5589B}>)
# 8: ((LAMBDA NIL :IN "/tmp/53933552D1DA4A480FEE593437772C7C-4114736410.lisp"))
# 9: (JUPYTER/COMMON-LISP::EVAL-AND-PRINT (WITH-SIMULATED-ROBOT (PERFORM (A MOTION (TYPE MOVING-TORSO) (JOINT-ANGLE 0.3)))) 0 NIL)
# 10: ((:METHOD JUPYTER:EVALUATE-FORM (JUPYTER/COMMON-LISP:KERNEL T T T)) #<unused argument> #<FORM-TRACKING-STREAM for "file /tmp/53933552D1DA4A480FEE593437772C7C-4114736410.lisp" {1004F80003}> CELL:4114736410.LISP.NEWEST NIL #<unused argument> #<unused argument>)
# 11: (JUPYTER/COMMON-LISP::REPL (urdf-proj:with-simulated-robot
#  (perform (a motion
#              (type moving-torso)
#              (joint-angle 0.3)))) CELL:4114736410.LISP.NEWEST NIL)
# 12: ((:METHOD JUPYTER:EVALUATE-CODE (JUPYTER/COMMON-LISP:KERNEL T)) #<unused argument> (urdf-proj:with-simulated-robot
#  (perform (a motion
#              (type moving-torso)
#              (joint-angle 0.3)))) CELL:4114736410.LISP.NEWEST NIL)
# 13: (JUPYTER::HANDLE-EXECUTE-REQUEST)
# 14: (JUPYTER::RUN-SHELL #<KERNEL {100AD761A3}>)
# 15: ((LABELS BORDEAUX-THREADS::%BINDING-DEFAULT-SPECIALS-WRAPPER :IN BORDEAUX-THREADS::BINDING-DEFAULT-SPECIALS))
# 16: ((FLET SB-UNIX::BODY :IN SB-THREAD::NEW-LISP-THREAD-TRAMPOLINE))
# 17: ((FLET "WITHOUT-INTERRUPTS-BODY-4" :IN SB-THREAD::NEW-LISP-THREAD-TRAMPOLINE))
# 18: ((FLET SB-THREAD::WITH-MUTEX-THUNK :IN SB-THREAD::NEW-LISP-THREAD-TRAMPOLINE))
# 19: ((FLET "WITHOUT-INTERRUPTS-BODY-1" :IN SB-THREAD::CALL-WITH-MUTEX))
# 20: (SB-THREAD::CALL-WITH-MUTEX #<CLOSURE (FLET SB-THREAD::WITH-MUTEX-THUNK :IN SB-THREAD::NEW-LISP-THREAD-TRAMPOLINE) {7FC0BBDAED7B}> #<MUTEX "thread result lock" owner: #<SB-THREAD:THREAD "SHELL Thread" RUNNING {100C1C7CC3}>> NIL T NIL)
# 21: (SB-THREAD::NEW-LISP-THREAD-TRAMPOLINE #<THREAD "SHELL Thread" RUNNING {100C1C7CC3}> NIL #<CLOSURE (LABELS BORDEAUX-THREADS::%BINDING-DEFAULT-SPECIALS-WRAPPER :IN BORDEAUX-THREADS::BINDING-DEFAULT-SPECIALS) {100C1C7C6B}> NIL)
# 22: ("foreign function: call_into_lisp")
# 23: ("foreign function: new_thread_trampoline")
# SB-INT:SIMPLE-STYLE-WARNING: undefined function: COMMON-LISP-USER::A
# SB-INT:SIMPLE-STYLE-WARNING: undefined function: COMMON-LISP-USER::JOINT-ANGLE
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MOTION
# SIMPLE-WARNING: undefined variable: COMMON-LISP-USER::MOVING-TORSO
# SB-INT:SIMPLE-STYLE-WARNING: undefined function: COMMON-LISP-USER::PERFORM
# SIMPLE-WARNING: The function TYPE is undefined, and its name is reserved by
#                 ANSI CL so that even if it were defined later, the code doing
#                 so would not be portable.
